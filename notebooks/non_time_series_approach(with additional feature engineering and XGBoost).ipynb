# %% [markdown]
# # Overview

# %% [markdown]
# kaggle competition: https://www.kaggle.com/c/walmart-recruiting-store-sales-forecasting/overview/evaluation

# %% [markdown]
# In this recruiting competition, job-seekers are provided with historical sales data for 45 Walmart stores located in different regions. Each store contains many departments, and participants must project the sales for each department in each store. To add to the challenge, selected holiday markdown events are included in the dataset. These markdowns are known to affect sales, but it is challenging to predict which departments are affected and the extent of the impact.

# %% [markdown]
# <div class="markdown-converter__text--rendered"><p>This competition is evaluated on the weighted mean absolute error (WMAE):</p>
# <p><span class="MathJax_Preview" style="color: inherit; display: none;"></span><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-9-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;block&quot;><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mtext>WMAE</mtext></mrow><mo>=</mo><mfrac><mn>1</mn><mrow><mo>&amp;#x2211;</mo><mrow class=&quot;MJX-TeXAtom-ORD&quot;><msub><mi>w</mi><mi>i</mi></msub></mrow></mrow></mfrac><munderover><mo>&amp;#x2211;</mo><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mi>n</mi></munderover><msub><mi>w</mi><mi>i</mi></msub><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mo stretchy=&quot;false&quot;>|</mo></mrow><msub><mi>y</mi><mi>i</mi></msub><mo>&amp;#x2212;</mo><msub><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mover><mi>y</mi><mo stretchy=&quot;false&quot;>&amp;#x005E;</mo></mover></mrow><mi>i</mi></msub><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mo stretchy=&quot;false&quot;>|</mo></mrow></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-125" style="width: 16.159em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.815em; height: 0px; font-size: 126%;"><span style="position: absolute; clip: rect(0.796em, 1012.7em, 3.971em, -999.997em); top: -2.548em; left: 0em;"><span class="mrow" id="MathJax-Span-126"><span class="texatom" id="MathJax-Span-127"><span class="mrow" id="MathJax-Span-128"><span class="mtext" id="MathJax-Span-129" style="font-family: STIXGeneral-Regular;">WMAE</span></span></span><span class="mo" id="MathJax-Span-130" style="font-family: STIXGeneral-Regular; padding-left: 0.343em;">=</span><span class="mfrac" id="MathJax-Span-131" style="padding-left: 0.343em;"><span style="display: inline-block; position: relative; width: 2.157em; height: 0px; margin-right: 0.116em; margin-left: 0.116em;"><span style="position: absolute; clip: rect(3.177em, 1000.4em, 4.198em, -999.997em); top: -4.702em; left: 50%; margin-left: -0.224em;"><span class="mn" id="MathJax-Span-132" style="font-family: STIXGeneral-Regular;">1</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; clip: rect(3.121em, 1002.04em, 4.481em, -999.997em); top: -3.285em; left: 50%; margin-left: -1.018em;"><span class="mrow" id="MathJax-Span-133"><span class="mo" id="MathJax-Span-134" style="font-family: STIXGeneral-Regular; vertical-align: 0.003em;">∑</span><span class="texatom" id="MathJax-Span-135" style="padding-left: 0.173em;"><span class="mrow" id="MathJax-Span-136"><span class="msubsup" id="MathJax-Span-137"><span style="display: inline-block; position: relative; width: 0.967em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.63em, 4.198em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-138" style="font-family: STIXGeneral-Italic;">w</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.852em; left: 0.683em;"><span class="mi" id="MathJax-Span-139" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; clip: rect(0.853em, 1002.16em, 1.25em, -999.997em); top: -1.301em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 2.157em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.08em;"></span></span></span></span><span class="munderover" id="MathJax-Span-140" style="padding-left: 0.173em;"><span style="display: inline-block; position: relative; width: 1.307em; height: 0px;"><span style="position: absolute; clip: rect(2.894em, 1001.19em, 4.651em, -999.997em); top: -4.022em; left: 0em;"><span class="mo" id="MathJax-Span-141" style="font-family: STIXSizeOneSym; vertical-align: -0.507em;">∑</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; clip: rect(3.404em, 1000.97em, 4.311em, -999.997em); top: -2.888em; left: 0.116em;"><span class="texatom" id="MathJax-Span-142"><span class="mrow" id="MathJax-Span-143"><span class="mi" id="MathJax-Span-144" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span class="mo" id="MathJax-Span-145" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">=</span><span class="mn" id="MathJax-Span-146" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; clip: rect(3.461em, 1000.34em, 4.198em, -999.997em); top: -5.213em; left: 0.456em;"><span class="mi" id="MathJax-Span-147" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">n</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-148" style="padding-left: 0.173em;"><span style="display: inline-block; position: relative; width: 0.967em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.63em, 4.198em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-149" style="font-family: STIXGeneral-Italic;">w</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.852em; left: 0.683em;"><span class="mi" id="MathJax-Span-150" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span><span class="texatom" id="MathJax-Span-151"><span class="mrow" id="MathJax-Span-152"><span class="mo" id="MathJax-Span-153" style="font-family: STIXVariants;">|</span></span></span><span class="msubsup" id="MathJax-Span-154"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-155" style="font-family: STIXGeneral-Italic;">y</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.852em; left: 0.456em;"><span class="mi" id="MathJax-Span-156" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span><span class="mo" id="MathJax-Span-157" style="font-family: STIXGeneral-Regular; padding-left: 0.23em;">−</span><span class="msubsup" id="MathJax-Span-158" style="padding-left: 0.23em;"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px;"><span style="position: absolute; clip: rect(3.121em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="texatom" id="MathJax-Span-159"><span class="mrow" id="MathJax-Span-160"><span class="munderover" id="MathJax-Span-161"><span style="display: inline-block; position: relative; width: 0.456em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-162" style="font-family: STIXGeneral-Italic;">y</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -4.079em; left: 0.06em;"><span style="height: 0em; vertical-align: 0em; width: 0.4em; display: inline-block; overflow: hidden;"></span><span class="mo" id="MathJax-Span-163" style="font-family: STIXGeneral-Regular;">̂&nbsp;<span style="height: 0em; vertical-align: 0em; margin-left: -0.224em;"></span></span><span style="display: inline-block; overflow: hidden; height: 1px; width: 0em;"></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.795em; left: 0.456em;"><span class="mi" id="MathJax-Span-164" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span><span class="texatom" id="MathJax-Span-165"><span class="mrow" id="MathJax-Span-166"><span class="mo" id="MathJax-Span-167" style="font-family: STIXVariants;">|</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.554em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.639em; border-left: 0px solid; width: 0px; height: 3.789em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><mrow class="MJX-TeXAtom-ORD"><mtext>WMAE</mtext></mrow><mo>=</mo><mfrac><mn>1</mn><mrow><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><msub><mi>w</mi><mi>i</mi></msub></mrow></mrow></mfrac><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mi>n</mi></munderover><msub><mi>w</mi><mi>i</mi></msub><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow><msub><mi>y</mi><mi>i</mi></msub><mo>−</mo><msub><mrow class="MJX-TeXAtom-ORD"><mover><mi>y</mi><mo stretchy="false">^</mo></mover></mrow><mi>i</mi></msub><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow></math></span></span></div><script type="math/tex; mode=display" id="MathJax-Element-9"> \textrm{WMAE} = \frac{1}{\sum{w_i}} \sum_{i=1}^n w_i | y_i - \hat{y}_i | </script></p>
# <p>where</p>
# <ul>
# <li>n is the number of rows</li>
# <li><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-10-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><msub><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mover><mi>y</mi><mo stretchy=&quot;false&quot;>&amp;#x005E;</mo></mover></mrow><mi>i</mi></msub></math>" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-168" style="width: 0.967em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px; font-size: 126%;"><span style="position: absolute; clip: rect(1.307em, 1000.74em, 2.611em, -999.997em); top: -2.208em; left: 0em;"><span class="mrow" id="MathJax-Span-169"><span class="msubsup" id="MathJax-Span-170"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px;"><span style="position: absolute; clip: rect(3.121em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="texatom" id="MathJax-Span-171"><span class="mrow" id="MathJax-Span-172"><span class="munderover" id="MathJax-Span-173"><span style="display: inline-block; position: relative; width: 0.456em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-174" style="font-family: STIXGeneral-Italic;">y</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -4.079em; left: 0.06em;"><span style="height: 0em; vertical-align: 0em; width: 0.4em; display: inline-block; overflow: hidden;"></span><span class="mo" id="MathJax-Span-175" style="font-family: STIXGeneral-Regular;">̂&nbsp;<span style="height: 0em; vertical-align: 0em; margin-left: -0.224em;"></span></span><span style="display: inline-block; overflow: hidden; height: 1px; width: 0em;"></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.795em; left: 0.456em;"><span class="mi" id="MathJax-Span-176" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.214em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.354em; border-left: 0px solid; width: 0px; height: 1.432em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mrow class="MJX-TeXAtom-ORD"><mover><mi>y</mi><mo stretchy="false">^</mo></mover></mrow><mi>i</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-10"> \hat{y}_i </script> is the predicted sales</li>
# <li><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-11-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><msub><mi>y</mi><mi>i</mi></msub></math>" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-177" style="width: 0.967em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px; font-size: 126%;"><span style="position: absolute; clip: rect(1.59em, 1000.74em, 2.611em, -999.997em); top: -2.208em; left: 0em;"><span class="mrow" id="MathJax-Span-178"><span class="msubsup" id="MathJax-Span-179"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-180" style="font-family: STIXGeneral-Italic;">y</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.852em; left: 0.456em;"><span class="mi" id="MathJax-Span-181" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.214em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.354em; border-left: 0px solid; width: 0px; height: 0.932em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>y</mi><mi>i</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-11"> y_i </script> is the actual sales</li>
# <li><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-12-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><msub><mi>w</mi><mi>i</mi></msub></math>" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-182" style="width: 1.25em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.967em; height: 0px; font-size: 126%;"><span style="position: absolute; clip: rect(1.59em, 1000.97em, 2.554em, -999.997em); top: -2.208em; left: 0em;"><span class="mrow" id="MathJax-Span-183"><span class="msubsup" id="MathJax-Span-184"><span style="display: inline-block; position: relative; width: 0.967em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.63em, 4.198em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-185" style="font-family: STIXGeneral-Italic;">w</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.852em; left: 0.683em;"><span class="mi" id="MathJax-Span-186" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.214em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 0.932em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>w</mi><mi>i</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-12"> w_i </script> are weights. w = 5 if the week is a holiday week, 1 otherwise</li>
# </ul>
# </div>

# %% [markdown]
# # Imports

# %% [markdown]
# Just import libraries that handle data visualization and simple preprocessing

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from scipy import stats
from scipy.special import boxcox1p

from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

import os
os.chdir('..')

# %% [markdown]
# # Read Data

# %% [markdown]
# We are loading train and test dataset splits prepared on EDA step.

# %%
train_ds = pd.read_csv('data/dataset.csv', header=0)
train_ds.Date = pd.to_datetime(train_ds.Date)

# %%
test_ds = pd.read_csv('data/test_dataset.csv', header=0)
test_ds.Date = pd.to_datetime(test_ds.Date)

# %%
train_ds.shape, test_ds.shape
# Out:
# ((421570, 16), (115064, 15))

# %% [markdown]
# # Prepare Directory for storing intermediate results

# %%
PATH = 'data/non_time_series_approach_with_additional_feature_engineering_and_xgboost'

# %%
if not os.path.exists(PATH):
    os.mkdir(PATH)
else:
    print(f'{PATH} exists!')
# Out:
# data/non_time_series_approach_with_additional_feature_engineering_and_xgboost exists!

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# 1. Date analysis
#     - Add week
#     - Add year
#
# **Some notes from competition:**
#
# For convenience, the four holidays fall within the following weeks in the dataset (not all holidays are in the data):
#
# Super Bowl: 12-Feb-10, 11-Feb-11, 10-Feb-12, 8-Feb-13
#
# Labor Day: 10-Sep-10, 9-Sep-11, 7-Sep-12, 6-Sep-13
#
# Thanksgiving: 26-Nov-10, 25-Nov-11, 23-Nov-12, 29-Nov-13
#
# Christmas: 31-Dec-10, 30-Dec-11, 28-Dec-12, 27-Dec-13
#
# 2. Holiday Analysis
#     - When holidays happen?
#     - Did IsHoliday column covert all holidays?

# %% [markdown]
# ## Cheatsheet for working with numerical features

# %% [markdown]
# ![title](https://i.stack.imgur.com/J8Ged.jpg)

# %% [markdown]
# ## Create Helper Functions

# %% [markdown]
#  > First, two plot functions that will help us.
#
# > The discrete plot is for finite numbers. We will use boxplot, to see the medians and interquartile ranges, and the striplot, which is a better way of seeing the distribution, even more when lots of outliers are present.
#
# > The continuous plot, as the name says, is for continuous variables. We will see the distribution of probabilities and use BoxCox to understand if there is increase of correlation and decrease of skewness for each variable. In some cases the process of transforming a variable can help, depending on the model.

# %%
def make_discrete_plot(dataframe, feature):
    fig = plt.figure(figsize=(20,8))
    gs = GridSpec(1,2)
    sns.boxplot(y=dataframe.Weekly_Sales, x=dataframe[feature], ax=fig.add_subplot(gs[0,0]))
    plt.ylabel('Sales', fontsize=16)
    plt.xlabel(feature, fontsize=16)
    sns.stripplot(y=dataframe.Weekly_Sales, x=dataframe[feature], ax=fig.add_subplot(gs[0,1]))
    plt.ylabel('Sales', fontsize=16)
    plt.xlabel(feature, fontsize=16)

# %%
def make_continuous_plot(dataframe, feature):
    
    fig = plt.figure(figsize=(18,15))
    gs = GridSpec(2,2)
    
    j = sns.scatterplot(y=dataframe['Weekly_Sales'], 
                        x=boxcox1p(dataframe[feature], 0.15), ax=fig.add_subplot(gs[0,1]), palette = 'blue')

    plt.title('BoxCox 0.15\n' + 'Corr: ' + str(np.round(dataframe['Weekly_Sales'].corr(boxcox1p(dataframe[feature], 0.15)),2)) +
              ', Skew: ' + str(np.round(stats.skew(boxcox1p(dataframe[feature], 0.15), nan_policy='omit'),2)))
    
    j = sns.scatterplot(y=dataframe['Weekly_Sales'], 
                        x=boxcox1p(dataframe[feature], 0.25), ax=fig.add_subplot(gs[1,0]), palette = 'blue')

    plt.title('BoxCox 0.25\n' + 'Corr: ' + str(np.round(dataframe['Weekly_Sales'].corr(boxcox1p(dataframe[feature], 0.25)),2)) +
              ', Skew: ' + str(np.round(stats.skew(boxcox1p(dataframe[feature], 0.25), nan_policy='omit'),2)))
    
    j = sns.histplot(dataframe[feature], ax=fig.add_subplot(gs[1,1]), color = 'green')

    plt.title('Distribution\n')
    
    j = sns.scatterplot(y=dataframe['Weekly_Sales'], 
                        x=dataframe[feature], ax=fig.add_subplot(gs[0,0]), color = 'red')

    plt.title('Linear\n' + 'Corr: ' + str(np.round(dataframe['Weekly_Sales'].corr(dataframe[feature]),2)) + ', Skew: ' + 
               str(np.round(stats.skew(dataframe[feature], nan_policy='omit'),2)))

# %%
def make_correlations_plot(dataframe):
    sns.set(style="white")

    corr = dataframe.corr()

    mask = np.triu(np.ones_like(corr, dtype=np.bool))

    f, ax = plt.subplots(figsize=(20, 15))

    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    plt.title('Correlation Matrix', fontsize=18)

    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

# %% [markdown]
# ## WeeklySales (Target)

# %% [markdown]
# Let's look at the target averaged across each store and department for each timestamp

# %%
train_ds.groupby('Date').Weekly_Sales.sum().plot(figsize = (20,3))
plt.title ('Walmart Weekly_Sales Overall')
plt.grid(axis = 'y', which = 'both');

# %% [markdown]
# So we notice here that yearly and seasonal patterns exist. For the christmas and new year period we have high inrease in sales and that happens for each year.
#
# The trend isn't really obvious. We will try to do series decomposition and see what happens.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose as sd

# %%
y = train_ds.groupby('Date').Weekly_Sales.sum()
y.index.freg = 'M-FRI'
dec = sd(y, model='additive')
f,ax = plt.subplots(4, figsize =(20,8))
ax[0].plot(dec.observed)
ax[1].plot(dec.trend)
ax[2].plot(dec.seasonal)
ax[3].plot(dec.resid);

# %% [markdown]
# Second plot from the above represents the general trend of our TS data set.  And we could see that there is an overall growing trend, however that is not rapid. Despite the fact that sales pick during the Christmas time in 2010 was higher to compare to 2011,  still with each year it shows the slightly growing trend.
#
# However, the question is, does this trend and seasonality applies to all stores or these are individual? To answer on this question, lets create set of subplots with sales volumes for every store.

# %%
fig = plt.figure(figsize = (20,15))
fig.suptitle('Walmart Weekly_Sales per every store\n(Name is the store No) ',y = 0.93,  fontsize = 16)
for s in list(range(1,46)):
    df_un0=train_ds[train_ds.Store == s].groupby('Date').Weekly_Sales.sum()
    ax = fig.add_subplot(9,5,s)
    #ax.plot(df_un0[:-len_pred])
    ax.plot(df_un0)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_title(s)
plt.show();

# %%
store_num = 1
s1 = train_ds[train_ds.Store == store_num][['Date', 'Dept', 'Weekly_Sales']]
fig = plt.figure(figsize = (20,30))
fig.suptitle(f'Walmart Weekly_Sales per {len(s1.Dept.unique())} departments in store No {store_num}\n(Name is department No) ',y = 0.93,  fontsize = 16)
for dep, num_in_plot in  zip(s1.Dept.unique(), list(range(1,len(s1.Dept.unique())))):
    df_un0=s1[s1.Dept == dep]
    df_un0.set_index('Date')
    df_un0 = df_un0[['Weekly_Sales']]
    ax = fig.add_subplot(16,5,num_in_plot)
    #ax.plot(df_un0[:-len_pred])
    ax.plot(df_un0)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_title(dep)
plt.show()

# %% [markdown]
# The answer is 'yes' for some bunch of stores and 'no' for others. It could be noticed that there is one store group that has a common seasonal pattern and trend. On the other hand: TS data of some stores contain much more noise compared to others; some represents climbing growth trend, while others vice-versa; there are few stores with individual seasonal factor.

# %% [markdown]
# So why it is important to know the seasonal and trend components of our data set for different stores?
#
# - 1st scenario
#
#     We could use the `SARIMAX` model, which is a handy and popular machine learning algorithm for TS predictions. This algorithm could be an alternative if we would make the overall sales predictions of Walmart, however, our purpose is to make forecasts for every store and every department. `SARIMAX` model implies only one target feature at a time. So, one way is to build a model and then loop it through each target feature. It could work in case if all target features would have identical seasonal and trend patterns. So with the power of the `pmdarima` library, we could approach the `auto_arima` function and specify p,d,q,P,D,Q parameters and loop the model all over the target features. However, in some stores, the picture is different from others. It means that we have to specify the individual parameters for particular stores and departments and use the `autoarima` function multiple times, which is not handy in terms of time and computational resources. Thus will drop this scenario for this case straight at a time.
#
#
# - 2nd scenario
#
#     `VARIMAX` algorithm is also an interesting tool in terms of predicting TS data with multiple target features at a time, which is our case. However, it shows the best performance, while targets have a particular level of causality. In our case, there are some stores that represent their own development of sales volume story. Thus we will skip this algorithm as well.
#
# The two interesting models that is recommended to apply to our dataset are `Random Forest` and `RNN`.
# Both can work in terms of prediction of multiple targets of sequential data and consider individuality for every target (in our case for every department of every store).

# %% [markdown]
# ## Correlations with Target

# %%
make_correlations_plot(train_ds)

# %% [markdown]
# We only see two features that have considerable correlation with the target:
#
#     - Size: 0.24
#     - Type: 0.18

# %% [markdown]
# ## Date -> (Week, Year)

# %%
train_ds['Week'] = train_ds.Date.dt.isocalendar().week
train_ds['Year'] = train_ds.Date.dt.isocalendar().year

# %%
train_ds[['Date', 'Year', 'Week']].head(2)
# Out:
#         Date  Year  Week
# 0 2010-02-05  2010     5
# 1 2010-02-12  2010     6

# %%
test_ds['Week'] = test_ds.Date.dt.isocalendar().week
test_ds['Year'] = test_ds.Date.dt.isocalendar().year

# %%
test_ds[['Date', 'Year', 'Week']].head(2)
# Out:
#         Date  Year  Week
# 0 2012-11-02  2012    44
# 1 2012-11-09  2012    45

# %% [markdown]
# ## IsHoliday

# %% [markdown]
# Let's look at the sales on weekly fashion for each year to compare side by side

# %%
list(train_ds.Year.unique())
# Out:
# [2010, 2011, 2012]

# %%
df_sales_2010_weekly = train_ds[train_ds.Year==2010]['Weekly_Sales'].groupby(train_ds['Week']).sum()
df_sales_2011_weekly = train_ds[train_ds.Year==2011]['Weekly_Sales'].groupby(train_ds['Week']).sum()
df_sales_2012_weekly = train_ds[train_ds.Year==2012]['Weekly_Sales'].groupby(train_ds['Week']).sum()

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x=df_sales_2010_weekly.index, y=df_sales_2010_weekly.values)
sns.lineplot(x=df_sales_2011_weekly.index, y=df_sales_2011_weekly.values)
sns.lineplot(x=df_sales_2012_weekly.index, y=df_sales_2012_weekly.values)
plt.grid()
plt.xticks(np.arange(1, 53, step=1))
plt.legend(['2010', '2011', '2012'], loc='best', fontsize=16)
plt.title('Overall Weekly Sales - Per Year', fontsize=18)
plt.ylabel('Sales', fontsize=16)
plt.xlabel('Week', fontsize=16)
plt.show()

# %%
list(train_ds[train_ds.IsHoliday].Week.unique())
# Out:
# [6, 36, 47, 52]

# %% [markdown]
# As we can see, there is one important Holiday not included in 'IsHoliday'. It's the Easter Day. It is always in a Sunday, but can fall on different weeks.
#
# Easter Dates are:
# - April 4, 2010: Week 13 (Train Set)
# - April 24, 2011: Week 16 (Train Set)
# - April 8 2012: Week 14 (Train&Test Set)
# - March 31 2013: Week 13 (Test Set)
#
# So, we can change to 'True' these Weeks in each Year.

# %%
train_ds.loc[(train_ds.Year==2010)&(train_ds.Week==13), 'IsHoliday'] = True
train_ds.loc[(train_ds.Year==2011)&(train_ds.Week==16), 'IsHoliday'] = True
train_ds.loc[(train_ds.Year==2012)&(train_ds.Week==14), 'IsHoliday'] = True

# %%
list(test_ds.Year.unique())
# Out:
# [2012, 2013]

# %%
test_ds.loc[(test_ds.Year==2012)&(test_ds.Week==14), 'IsHoliday'] = True
test_ds.loc[(test_ds.Year==2013)&(test_ds.Week==13), 'IsHoliday'] = True

# %% [markdown]
# Let's look at the sales on holiday weeks again

# %%
weekly_sales_mean = train_ds['Weekly_Sales'].groupby(train_ds['Week']).mean()

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x=weekly_sales_mean.index, y=weekly_sales_mean.values)
plt.grid()
plt.xticks(np.arange(1, 53, step=1))
plt.legend(['Mean'], loc='best', fontsize=16)
plt.title('Mean Weekly Sales', fontsize=18)
plt.ylabel('Sales', fontsize=16)
plt.xlabel('Week', fontsize=16)
plt.axvline(6, color='red')
plt.axvline(13, color='red')
plt.axvline(14, color='red')
plt.axvline(36, color='red')
plt.axvline(47, color='red')
plt.axvline(52, color='red')
plt.show()

# %% [markdown]
# Looking at the 52th Week I would say that it has some issues. It's now always correct that 52th week is christmas. It's sometimes 51th.
#
# Let's see the full list across years:
# - 2010: week 51
# - 2011: week 51
# - 2012: week 52
# - 2013: week 52

# %% [markdown]
# So we do some changes here in both Train and Test Set

# %%
pass

# %% [markdown]
# ## IsHoliday(revisited)

# %%
make_discrete_plot(train_ds, 'IsHoliday')

# %% [markdown]
# As we see we have different distribution for Holiday and Non-Holiday weeks

# %% [markdown]
# ## Week

# %%
make_discrete_plot(train_ds, 'Week')

# %% [markdown]
# We can see that for some weeks we have high sales compared to others. But from analysis of IsHoliday we can say that that information is already encoded in IsHoliday feature.
#
# BUT we could additionally create feature `High_Sales` where we set to True all weeks that have seasonally high sales.

# %% [markdown]
# ## Year

# %%
make_discrete_plot(train_ds, "Year")

# %% [markdown]
# All year has almost the same amount and distribution of sales. We don't have tails (connected to last weeks of 2012 on christmas time) for 2012 year, since it's included in test data split.

# %% [markdown]
# ## Size

# %% [markdown]
# It's a numeric type. Let's see how it's correlated with target. Maybe do some engineering on it.

# %%
make_discrete_plot(train_ds, 'Size')

# %% [markdown]
# We see that there is a positive correlation with the target. We keep the `Size` as it is. Maybe generate polynomial features and that's would be enough!

# %%
train_ds[['Weekly_Sales', 'Size']].corr()
# Out:
#               Weekly_Sales      Size
# Weekly_Sales      1.000000  0.243828
# Size              0.243828  1.000000

# %% [markdown]
# ## Type

# %% [markdown]
# It's a categorical type. We analyze it with a discrete plot and see what can be done with this feature.

# %%
make_discrete_plot(train_ds, 'Type')

# %% [markdown]
# Here we see that for each category there is a specific distribution of target. We must convert given feature into the ordinal one, considering the right ordering of given categories (C->B->A to get kind of positive correlation)

# %%
def type_converter(value):
    """Converts Type feature into ordinal one using"""
    if value == 'A': return 3
    elif value == 'B': return 2
    elif value == 'C': return 1
    else: return 0

# %%
def rev_type_converter(value):
    """Reverse conversion of Type feature from ordinal to categorical"""
    if value == 3: return 'A'
    elif value == 2: return 'B'
    elif value == 1: return 'C'
    else: return None

# %%
train_ds.loc[:, 'Type'] = train_ds.Type.apply(type_converter)

# %%
test_ds.loc[:, 'Type'] = test_ds.Type.apply(type_converter)

# %%
make_discrete_plot(train_ds, 'Type')

# %% [markdown]
# ## Dept

# %%
make_discrete_plot(train_ds, 'Dept')

# %% [markdown]
# We could change the ordering of departments, according to average sales in each department.
# This way Department will have ordinal feature type.

# %% [markdown]
# Check if both dataset splits have same `Dept` values

# %%
set(train_ds.Dept.unique()) == set(test_ds.Dept.unique())
# Out:
# True

# %%
dept_mapper_dict = {
    dept_id: idx + 1 
    for idx, dept_id in 
    train_ds.groupby('Dept')[
        ['Weekly_Sales']
    ].mean().sort_values(by='Weekly_Sales').reset_index().Dept.to_dict().items()
}

# %% [markdown]
# apply to dataset splits

# %%
train_ds.loc[:, 'Dept'] = train_ds.Dept.apply(lambda x: dept_mapper_dict[x])
test_ds.loc[:, 'Dept'] = test_ds.Dept.apply(lambda x: dept_mapper_dict[x])

# %% [markdown]
# ## Store

# %%
make_discrete_plot(train_ds, "Store")

# %% [markdown]
# We could change the ordering of Stores, according to average sales in each store.
# After that the type of feature `Store` become ordinal.

# %% [markdown]
# Check if both dataset splits have same `Dept` values

# %%
set(train_ds.Store.unique()) == set(test_ds.Store.unique())
# Out:
# True

# %%
store_mapper_dict = {
    store_id: idx + 1 
    for idx, store_id in 
    train_ds.groupby('Store')[
        ['Weekly_Sales']
    ].mean().sort_values(by='Weekly_Sales').reset_index().Store.to_dict().items()
}

# %% [markdown]
# apply to dataset splits

# %%
train_ds.loc[:, 'Store'] = train_ds.Store.apply(lambda x: store_mapper_dict[x])
test_ds.loc[:, 'Store'] = test_ds.Store.apply(lambda x: store_mapper_dict[x])

# %% [markdown]
# ## Temperature

# %%
make_continuous_plot(train_ds, 'Temperature')

# %% [markdown]
# Although skewness changes, correlation doesn't seem to change at all. We can decide to drop it.

# %% [markdown]
# ## Fuel_Price

# %%
make_continuous_plot(train_ds, 'Fuel_Price')

# %% [markdown]
# Although skewness changes, correlation doesn't seem to change at all. We can decide to drop it.

# %% [markdown]
# ## MarkDownX (1,2,3,4,5)

# %%
make_continuous_plot(train_ds, 'MarkDown1')

# %% [markdown]
# Uncommented because it takes too much time for plotting

# %%
# make_continuous_plot(train_ds, 'MarkDown2')

# make_continuous_plot(train_ds, 'MarkDown3')

# make_continuous_plot(train_ds, 'MarkDown4')

# make_continuous_plot(train_ds, 'MarkDown5')

# %% [markdown]
# Although skewness changes, correlation doesn't seem to change at all. We can decide to drop it.

# %% [markdown]
# ## CPI

# %%
make_continuous_plot(train_ds, 'CPI')

# %%
test_ds[test_ds.CPI.notna()].Week.hist();

# %%
test_ds[test_ds.CPI.isna()].Week.hist();

# %%
test_ds.CPI.isna().sum()/test_ds.shape[0]
# Out:
# 0.33165890287144545

# %% [markdown]
# Although skewness changes, correlation doesn't seem to change at all.
#
# **BUT** if we look at some ranges of it's values like:
#
# - (9.45 - 9.82)
# - (10.7 - 10.9)
# - (10.9 - 11.1)
# - (11.2 - 11.6)
#
# there are kind of different overall distributions of Weekly_Sales. We could do binning on that feature and use it for predictions.
#
# BUT the problem is that we have 33% of missing values in test dataset. Imputation of so much values is bad, so we have to remove given feature.

# %% [markdown]
# ## Unemployment

# %%
make_continuous_plot(train_ds, 'Unemployment')

# %% [markdown]
# Although skewness changes, correlation doesn't seem to change at all. We can decide to drop it.

# %% [markdown]
# Though, we could do binning like in CPI on that feature too.

# %% [markdown]
# # Feature Selection

# %%
train_ds.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size',
#        'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3',
#        'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'Week', 'Year'],
#       dtype='object')

# %% [markdown]
# We need to select features to fit models. We use previous analysis of features, correlations with target, etc to decide which features must be used for fitting models.
#
# - Store: Has considerable correlation with target (ADD)
# - Dept: Has considerable correlation with target (ADD)
# - Date: Can't be used directly for predictions because of it's data type. Before that it will be used for data splitting and cross validation. (REMOVE)
#
# - IsHoliday: Has considerable correlation with target (ADD)
# - Type: Has considerable correlation with target (ADD)
# - Size: Has considerable correlation with target (ADD)
# - Temperature: Doesn't have any meaningful correlations with target (REMOVE)
# - Fuel_Price: Doesn't have any meaningful correlations with target (REMOVE)
# - Markdown1: Doesn't have any meaningful correlations with target (REMOVE)
# - Markdown2: Doesn't have any meaningful correlations with target (REMOVE)
# - Markdown3: Doesn't have any meaningful correlations with target (REMOVE)
# - Markdown4: Doesn't have any meaningful correlations with target (REMOVE)
# - Markdown5: Doesn't have any meaningful correlations with target (REMOVE)
# - CPI: Doesn't have any meaningful correlations with target (REMOVE)
# - Unemployment: Doesn't have any meaningful correlations with target (REMOVE)
# - Week: Has some correlations with target, especially for holiday weeks. Let's include that feature also (ADD)
# - Year: can be removed since sales per year is equally distributed. But let's try to keep it for now (ADD)

# %%
train_ds = train_ds[['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size', 'Week', 'Year']]

# %%
test_ds = test_ds[['Store', 'Dept', 'Date', 'IsHoliday', 'Type', 'Size', 'Week', 'Year']]

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Model Functions

# %% [markdown]
# <div class="markdown-converter__text--rendered"><p>This competition is evaluated on the weighted mean absolute error (WMAE):</p>
# <p><span class="MathJax_Preview" style="color: inherit; display: none;"></span><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-9-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;block&quot;><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mtext>WMAE</mtext></mrow><mo>=</mo><mfrac><mn>1</mn><mrow><mo>&amp;#x2211;</mo><mrow class=&quot;MJX-TeXAtom-ORD&quot;><msub><mi>w</mi><mi>i</mi></msub></mrow></mrow></mfrac><munderover><mo>&amp;#x2211;</mo><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mi>n</mi></munderover><msub><mi>w</mi><mi>i</mi></msub><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mo stretchy=&quot;false&quot;>|</mo></mrow><msub><mi>y</mi><mi>i</mi></msub><mo>&amp;#x2212;</mo><msub><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mover><mi>y</mi><mo stretchy=&quot;false&quot;>&amp;#x005E;</mo></mover></mrow><mi>i</mi></msub><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mo stretchy=&quot;false&quot;>|</mo></mrow></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-125" style="width: 16.159em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.815em; height: 0px; font-size: 126%;"><span style="position: absolute; clip: rect(0.796em, 1012.7em, 3.971em, -999.997em); top: -2.548em; left: 0em;"><span class="mrow" id="MathJax-Span-126"><span class="texatom" id="MathJax-Span-127"><span class="mrow" id="MathJax-Span-128"><span class="mtext" id="MathJax-Span-129" style="font-family: STIXGeneral-Regular;">WMAE</span></span></span><span class="mo" id="MathJax-Span-130" style="font-family: STIXGeneral-Regular; padding-left: 0.343em;">=</span><span class="mfrac" id="MathJax-Span-131" style="padding-left: 0.343em;"><span style="display: inline-block; position: relative; width: 2.157em; height: 0px; margin-right: 0.116em; margin-left: 0.116em;"><span style="position: absolute; clip: rect(3.177em, 1000.4em, 4.198em, -999.997em); top: -4.702em; left: 50%; margin-left: -0.224em;"><span class="mn" id="MathJax-Span-132" style="font-family: STIXGeneral-Regular;">1</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; clip: rect(3.121em, 1002.04em, 4.481em, -999.997em); top: -3.285em; left: 50%; margin-left: -1.018em;"><span class="mrow" id="MathJax-Span-133"><span class="mo" id="MathJax-Span-134" style="font-family: STIXGeneral-Regular; vertical-align: 0.003em;">∑</span><span class="texatom" id="MathJax-Span-135" style="padding-left: 0.173em;"><span class="mrow" id="MathJax-Span-136"><span class="msubsup" id="MathJax-Span-137"><span style="display: inline-block; position: relative; width: 0.967em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.63em, 4.198em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-138" style="font-family: STIXGeneral-Italic;">w</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.852em; left: 0.683em;"><span class="mi" id="MathJax-Span-139" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; clip: rect(0.853em, 1002.16em, 1.25em, -999.997em); top: -1.301em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 2.157em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.08em;"></span></span></span></span><span class="munderover" id="MathJax-Span-140" style="padding-left: 0.173em;"><span style="display: inline-block; position: relative; width: 1.307em; height: 0px;"><span style="position: absolute; clip: rect(2.894em, 1001.19em, 4.651em, -999.997em); top: -4.022em; left: 0em;"><span class="mo" id="MathJax-Span-141" style="font-family: STIXSizeOneSym; vertical-align: -0.507em;">∑</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; clip: rect(3.404em, 1000.97em, 4.311em, -999.997em); top: -2.888em; left: 0.116em;"><span class="texatom" id="MathJax-Span-142"><span class="mrow" id="MathJax-Span-143"><span class="mi" id="MathJax-Span-144" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span class="mo" id="MathJax-Span-145" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">=</span><span class="mn" id="MathJax-Span-146" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; clip: rect(3.461em, 1000.34em, 4.198em, -999.997em); top: -5.213em; left: 0.456em;"><span class="mi" id="MathJax-Span-147" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">n</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-148" style="padding-left: 0.173em;"><span style="display: inline-block; position: relative; width: 0.967em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.63em, 4.198em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-149" style="font-family: STIXGeneral-Italic;">w</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.852em; left: 0.683em;"><span class="mi" id="MathJax-Span-150" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span><span class="texatom" id="MathJax-Span-151"><span class="mrow" id="MathJax-Span-152"><span class="mo" id="MathJax-Span-153" style="font-family: STIXVariants;">|</span></span></span><span class="msubsup" id="MathJax-Span-154"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-155" style="font-family: STIXGeneral-Italic;">y</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.852em; left: 0.456em;"><span class="mi" id="MathJax-Span-156" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span><span class="mo" id="MathJax-Span-157" style="font-family: STIXGeneral-Regular; padding-left: 0.23em;">−</span><span class="msubsup" id="MathJax-Span-158" style="padding-left: 0.23em;"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px;"><span style="position: absolute; clip: rect(3.121em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="texatom" id="MathJax-Span-159"><span class="mrow" id="MathJax-Span-160"><span class="munderover" id="MathJax-Span-161"><span style="display: inline-block; position: relative; width: 0.456em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-162" style="font-family: STIXGeneral-Italic;">y</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -4.079em; left: 0.06em;"><span style="height: 0em; vertical-align: 0em; width: 0.4em; display: inline-block; overflow: hidden;"></span><span class="mo" id="MathJax-Span-163" style="font-family: STIXGeneral-Regular;">̂&nbsp;<span style="height: 0em; vertical-align: 0em; margin-left: -0.224em;"></span></span><span style="display: inline-block; overflow: hidden; height: 1px; width: 0em;"></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.795em; left: 0.456em;"><span class="mi" id="MathJax-Span-164" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span><span class="texatom" id="MathJax-Span-165"><span class="mrow" id="MathJax-Span-166"><span class="mo" id="MathJax-Span-167" style="font-family: STIXVariants;">|</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.554em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.639em; border-left: 0px solid; width: 0px; height: 3.789em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><mrow class="MJX-TeXAtom-ORD"><mtext>WMAE</mtext></mrow><mo>=</mo><mfrac><mn>1</mn><mrow><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><msub><mi>w</mi><mi>i</mi></msub></mrow></mrow></mfrac><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mi>n</mi></munderover><msub><mi>w</mi><mi>i</mi></msub><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow><msub><mi>y</mi><mi>i</mi></msub><mo>−</mo><msub><mrow class="MJX-TeXAtom-ORD"><mover><mi>y</mi><mo stretchy="false">^</mo></mover></mrow><mi>i</mi></msub><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow></math></span></span></div><script type="math/tex; mode=display" id="MathJax-Element-9"> \textrm{WMAE} = \frac{1}{\sum{w_i}} \sum_{i=1}^n w_i | y_i - \hat{y}_i | </script></p>
# <p>where</p>
# <ul>
# <li>n is the number of rows</li>
# <li><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-10-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><msub><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mover><mi>y</mi><mo stretchy=&quot;false&quot;>&amp;#x005E;</mo></mover></mrow><mi>i</mi></msub></math>" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-168" style="width: 0.967em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px; font-size: 126%;"><span style="position: absolute; clip: rect(1.307em, 1000.74em, 2.611em, -999.997em); top: -2.208em; left: 0em;"><span class="mrow" id="MathJax-Span-169"><span class="msubsup" id="MathJax-Span-170"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px;"><span style="position: absolute; clip: rect(3.121em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="texatom" id="MathJax-Span-171"><span class="mrow" id="MathJax-Span-172"><span class="munderover" id="MathJax-Span-173"><span style="display: inline-block; position: relative; width: 0.456em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-174" style="font-family: STIXGeneral-Italic;">y</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -4.079em; left: 0.06em;"><span style="height: 0em; vertical-align: 0em; width: 0.4em; display: inline-block; overflow: hidden;"></span><span class="mo" id="MathJax-Span-175" style="font-family: STIXGeneral-Regular;">̂&nbsp;<span style="height: 0em; vertical-align: 0em; margin-left: -0.224em;"></span></span><span style="display: inline-block; overflow: hidden; height: 1px; width: 0em;"></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.795em; left: 0.456em;"><span class="mi" id="MathJax-Span-176" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.214em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.354em; border-left: 0px solid; width: 0px; height: 1.432em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mrow class="MJX-TeXAtom-ORD"><mover><mi>y</mi><mo stretchy="false">^</mo></mover></mrow><mi>i</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-10"> \hat{y}_i </script> is the predicted sales</li>
# <li><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-11-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><msub><mi>y</mi><mi>i</mi></msub></math>" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-177" style="width: 0.967em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px; font-size: 126%;"><span style="position: absolute; clip: rect(1.59em, 1000.74em, 2.611em, -999.997em); top: -2.208em; left: 0em;"><span class="mrow" id="MathJax-Span-178"><span class="msubsup" id="MathJax-Span-179"><span style="display: inline-block; position: relative; width: 0.74em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.46em, 4.425em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-180" style="font-family: STIXGeneral-Italic;">y</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.852em; left: 0.456em;"><span class="mi" id="MathJax-Span-181" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.214em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.354em; border-left: 0px solid; width: 0px; height: 0.932em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>y</mi><mi>i</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-11"> y_i </script> is the actual sales</li>
# <li><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-12-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><msub><mi>w</mi><mi>i</mi></msub></math>" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-182" style="width: 1.25em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.967em; height: 0px; font-size: 126%;"><span style="position: absolute; clip: rect(1.59em, 1000.97em, 2.554em, -999.997em); top: -2.208em; left: 0em;"><span class="mrow" id="MathJax-Span-183"><span class="msubsup" id="MathJax-Span-184"><span style="display: inline-block; position: relative; width: 0.967em; height: 0px;"><span style="position: absolute; clip: rect(3.404em, 1000.63em, 4.198em, -999.997em); top: -4.022em; left: 0em;"><span class="mi" id="MathJax-Span-185" style="font-family: STIXGeneral-Italic;">w</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span><span style="position: absolute; top: -3.852em; left: 0.683em;"><span class="mi" id="MathJax-Span-186" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span style="display: inline-block; width: 0px; height: 4.028em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.214em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 0.932em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>w</mi><mi>i</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-12"> w_i </script> are weights. w = 5 if the week is a holiday week, 1 otherwise</li>
# </ul>
# </div>

# %% [markdown]
# As we can see in the figure below, the evaluation is based on Weighted Mean Absolute Error (WMAE), with a weight of 5 for Holiday Weeks and 1 otherwise.
#
# So, turning the formula into a function, since we can't use GridSearchCV or RandomSearchCV (it's because randomly chosen subsets would have different losses depending on the holiday weeks)

# %%
def WMAE(dataset, real, predicted):
    weights = dataset.IsHoliday.apply(lambda x: 5 if x else 1)
    return np.round(np.sum(weights*abs(real-predicted))/(np.sum(weights)), 2)

# %% [markdown]
# ### XGBoost

# %% [markdown]
# ### **General Parameters**
#
# These define the overall functionality of XGBoost.
#
# 1. **booster [default=gbtree]**
#   - Select the type of model to run at each iteration. It has 2 options:
#     - gbtree: tree-based models
#     - gblinear: linear models
# 2. **silent [default=0]:**
#   - Silent mode is activated is set to 1, i.e. no running messages will be printed.
#   - It&#39;s generally good to keep it 0 as the messages might help in understanding the model.
# 3. **nthread [default to maximum number of threads available if not set]**
#   - This is used for parallel processing and number of cores in the system should be entered
#   - If you wish to run on all cores, value should not be entered and algorithm will detect automatically
#
# There are 2 more parameters which are set automatically by XGBoost and you need not worry about them. Lets move on to Booster parameters.
#
# ### **Booster Parameters**
#
# Though there are 2 types of boosters, I&#39;ll consider only **tree booster** here because it always outperforms the linear booster and thus the later is rarely used.
#
# 1. **eta [default=0.3]**
#   - Analogous to learning rate in GBM
#   - Makes the model more robust by shrinking the weights on each step
#   - Typical final values to be used: 0.01-0.2
# 2. **min\_child\_weight [default=1]**
#   - Defines the minimum sum of weights of all observations required in a child.
#   - This is similar to **min\_child\_leaf** in GBM but not exactly. This refers to min &quot;sum of weights&quot; of observations while GBM has min &quot;number of observations&quot;.
#   - Used to control over-fitting. Higher values prevent a model from learning relations which might be highly specific to the particular sample selected for a tree.
#   - Too high values can lead to under-fitting hence, it should be tuned using CV.
# 3. **max\_depth [default=6]**
#   - The maximum depth of a tree, same as GBM.
#   - Used to control over-fitting as higher depth will allow model to learn relations very specific to a particular sample.
#   - Should be tuned using CV.
#   - Typical values: 3-10
# 4. **max\_leaf\_nodes**
#   - The maximum number of terminal nodes or leaves in a tree.
#   - Can be defined in place of max\_depth. Since binary trees are created, a depth of &#39;n&#39; would produce a maximum of 2^n leaves.
#   - If this is defined, GBM will ignore max\_depth.
# 5. **gamma [default=0]**
#   - A node is split only when the resulting split gives a positive reduction in the loss function. Gamma specifies the minimum loss reduction required to make a split.
#   - Makes the algorithm conservative. The values can vary depending on the loss function and should be tuned.
# 6. **max\_delta\_step [default=0]**
#   - In maximum delta step we allow each tree&#39;s weight estimation to be. If the value is set to 0, it means there is no constraint. If it is set to a positive value, it can help making the update step more conservative.
#   - Usually this parameter is not needed, but it might help in logistic regression when class is extremely imbalanced.
#   - This is generally not used but you can explore further if you wish.
# 7. **subsample [default=1]**
#   - Same as the subsample of GBM. Denotes the fraction of observations to be randomly samples for each tree.
#   - Lower values make the algorithm more conservative and prevents overfitting but too small values might lead to under-fitting.
#   - Typical values: 0.5-1
# 8. **colsample\_bytree [default=1]**
#   - Similar to max\_features in GBM. Denotes the fraction of columns to be randomly samples for each tree.
#   - Typical values: 0.5-1
# 9. **colsample\_bylevel [default=1]**
#   - Denotes the subsample ratio of columns for each split, in each level.
#   - I don&#39;t use this often because subsample and colsample\_bytree will do the job for you. but you can explore further if you feel so.
# 10. **lambda [default=1]**
#   - L2 regularization term on weights (analogous to Ridge regression)
#   - This used to handle the regularization part of XGBoost. Though many data scientists don&#39;t use it often, it should be explored to reduce overfitting.
# 11. **alpha [default=0]**
#   - L1 regularization term on weight (analogous to Lasso regression)
#   - Can be used in case of very high dimensionality so that the algorithm runs faster when implemented
# 12. **scale\_pos\_weight [default=1]**
#   - A value greater than 0 should be used in case of high class imbalance as it helps in faster convergence.
#
# ### **Learning Task Parameters**
#
# These parameters are used to define the optimization objective the metric to be calculated at each step.
#
# 1. **objective [default=reg:linear]**
#   - This defines the loss function to be minimized. Mostly used values are:
#     - **binary:logistic** –logistic regression for binary classification, returns predicted probability (not class)
#     - **multi:softmax** –multiclass classification using the softmax objective, returns predicted class (not probabilities)
#       - you also need to set an additional **num\_class** (number of classes) parameter defining the number of unique classes
#     - **multi:softprob** –same as softmax, but returns predicted probability of each data point belonging to each class.
# 2. **eval\_metric [default according to objective]**
#   - The metric to be used for validation data.
#   - The default values are rmse for regression and error for classification.
#   - Typical values are:
#     - **rmse** – root mean square error
#     - **mae** – mean absolute error
#     - **logloss** – negative log-likelihood
#     - **error** – Binary classification error rate (0.5 threshold)
#     - **merror** – Multiclass classification error rate
#     - **mlogloss** – Multiclass logloss
#     - **auc:** Area under the curve
# 3. **seed [default=0]**
#   - The random number seed.
#   - Can be used for generating reproducible results and also for parameter tuning.

# %% [markdown]
# ### **General Approach for Parameter Tuning**
#
# We will use an approach similar to that of GBM here. The various steps to be performed are:
#
# 1. Choose a relatively **high learning rate**. Generally a learning rate of 0.1 works but somewhere between 0.05 to 0.3 should work for different problems. Determine the **optimum number of trees for this learning rate**. XGBoost has a very useful function called as &quot;cv&quot; which performs cross-validation at each boosting iteration and thus returns the optimum number of trees required.
# 2. **Tune tree-specific parameters** ( max\_depth, min\_child\_weight, gamma, subsample, colsample\_bytree) for decided learning rate and number of trees. Note that we can choose different parameters to define a tree and I&#39;ll take up an example here.
# 3. Tune **regularization parameters** (lambda, alpha) for xgboost which can help reduce model complexity and enhance performance.
# 4. **Lower the learning rate** and decide the optimal parameters .

# %% [markdown]
# some references to tuning XGBRegressor
# - https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/
# - https://kevinvecmanis.io/machine%20learning/hyperparameter%20tuning/dataviz/python/2019/05/11/XGBoost-Tuning-Visual-Guide.html#gamma

# %%
def xgboost(n_estimators, learning_rates):
    result = []
    for estimator in n_estimators:
        for lr in learning_rates:
            wmaes_cv = []
            for i in range(1,5):
                print('k:', i, ', n_estimators:', estimator, ', learning_rate:', lr)
                x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.3)
                GB = XGBRegressor(
                    n_estimators=estimator,
                    learning_rate=lr,
                    max_depth=5,
                    min_child_weight=1,
                    gamma=0,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    objective= 'reg:squarederror',
                    n_jobs=-1,
                    scale_pos_weight=1,
                    seed=42
                )
                GB.fit(x_train, y_train)
                predicted = GB.predict(x_test)
                wmaes_cv.append(WMAE(x_test, y_test, predicted))
            print('WMAE:', np.mean(wmaes_cv))
            result.append({'Learning Rate': lr, 'Estimators': estimator, 'WMAE': np.mean(wmaes_cv)})
    return pd.DataFrame(result)

# %%
def xgboost_II(n_estimators, learning_rate, max_depths, gammas):
    result = []
    for depth in max_depths:
        for gamma in gammas:
            wmaes_cv = []
            for i in range(1,5):
                print('k:', i, ', max_depth:', depth, 'gamma', gamma)
                x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.3)
                GB = XGBRegressor(
                        n_estimators=n_estimators,
                        learning_rate=learning_rate,
                        max_depth=depth,
                        min_child_weight=1,
                        gamma=gamma,
                        subsample=0.8,
                        colsample_bytree=0.8,
                        objective= 'reg:squarederror',
                        n_jobs=-1,
                        scale_pos_weight=1,
                        seed=42
                    )
                GB.fit(x_train, y_train)
                predicted = GB.predict(x_test)
                wmaes_cv.append(WMAE(x_test, y_test, predicted))
            print('WMAE:', np.mean(wmaes_cv))
            result.append(
                {
                    'Learning Rate': learning_rate,
                    'Estimators': n_estimators, 
                    'Max Depth': depth, 
                    'Gamma': gamma,
                    'WMAE': np.mean(wmaes_cv)
                }
            )

    return pd.DataFrame(result)

# %%
def xgboost_III(n_estimators, learning_rate, max_depth, gamma, lambdas):
    result = []
    for lam in lambdas:
        wmaes_cv = []
        for i in range(1,5):
            print('k:', i, ', lambda:', lam)
            x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.3)
            GB = XGBRegressor(
                    n_estimators=n_estimators,
                    learning_rate=learning_rate,
                    max_depth=max_depth,
                    min_child_weight=1,
                    gamma=gamma,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    objective= 'reg:squarederror',
                    n_jobs=-1,
                    scale_pos_weight=1,
                    reg_lambda=lam,
                    seed=42
                )
            GB.fit(x_train, y_train)
            predicted = GB.predict(x_test)
            wmaes_cv.append(WMAE(x_test, y_test, predicted))
        print('WMAE:', np.mean(wmaes_cv))
        result.append(
            {
                'Learning Rate': learning_rate,
                'Estimators': n_estimators, 
                'Max Depth': max_depth, 
                'Gamma': gamma,
                'Lambda':lam,
                'WMAE': np.mean(wmaes_cv)
            }
        )

    return pd.DataFrame(result)

# %% [markdown]
# ### Training Model

# %% [markdown]
# > Preparing Train Set.

# %% [markdown]
# Convert all columns to float

# %%
def to_float(dataframe):
    dataframe_copy = dataframe.copy(deep=True)
    for column in dataframe.columns:
        dataframe_copy.loc[:, column] = dataframe[column].astype(float)
    
    return dataframe_copy

# %%
X_train = to_float(train_ds[['Store','Dept','IsHoliday','Size','Week','Type','Year']])
Y_train = train_ds['Weekly_Sales']

# %% [markdown]
# > Tuning 'n_estimators' and 'learning_rate'.
#
# > Here, it is possible to test a lot of values. Those are the final ones, after a bit of testing.

# %%
xgboost(
    [200, 500, 750, 1000, 1200, 1500], 
    [1, 0.5, 0.3]
)
# Out:
# k: 1 , n_estimators: 200 , learning_rate: 1
# k: 2 , n_estimators: 200 , learning_rate: 1
# k: 3 , n_estimators: 200 , learning_rate: 1
# k: 4 , n_estimators: 200 , learning_rate: 1
# WMAE: 2921.6974999999998
# k: 1 , n_estimators: 200 , learning_rate: 0.5
# k: 2 , n_estimators: 200 , learning_rate: 0.5
# k: 3 , n_estimators: 200 , learning_rate: 0.5
# k: 4 , n_estimators: 200 , learning_rate: 0.5
# WMAE: 2911.9375
# k: 1 , n_estimators: 200 , learning_rate: 0.3
# k: 2 , n_estimators: 200 , learning_rate: 0.3
# k: 3 , n_estimators: 200 , learning_rate: 0.3
# k: 4 , n_estimators: 200 , learning_rate: 0.3
# WMAE: 3171.5325
# k: 1 , n_estimators: 500 , learning_rate: 1
# k: 2 , n_estimators: 500 , learning_rate: 1
# k: 3 , n_estimators: 500 , learning_rate: 1
# k: 4 , n_estimators: 500 , learning_rate: 1
# WMAE: 2447.0975
# k: 1 , n_estimators: 500 , learning_rate: 0.5
# k: 2 , n_estimators: 500 , learning_rate: 0.5
# k: 3 , n_estimators: 500 , learning_rate: 0.5
# ...

# %% [markdown]
# > The result by the time I run it is 0.5 and 1500.

# %% [markdown]
# > Tuning `max_depth` and `Gamma`.

# %%
xgboost_II(
    n_estimators=1500, 
    learning_rate=0.5, 
    max_depths=[7, 8, 9, 10, 20],
    gammas=[0.0, 0.5, 1.0, 10.0]
)
# Out:
# k: 1 , max_depth: 7 gamma 0.0
# k: 2 , max_depth: 7 gamma 0.0
# k: 3 , max_depth: 7 gamma 0.0
# k: 4 , max_depth: 7 gamma 0.0
# WMAE: 1571.7849999999999
# k: 1 , max_depth: 7 gamma 0.5
# k: 2 , max_depth: 7 gamma 0.5
# k: 3 , max_depth: 7 gamma 0.5
# k: 4 , max_depth: 7 gamma 0.5
# WMAE: 1588.685
# k: 1 , max_depth: 7 gamma 1.0
# k: 2 , max_depth: 7 gamma 1.0
# k: 3 , max_depth: 7 gamma 1.0
# k: 4 , max_depth: 7 gamma 1.0
# WMAE: 1594.8999999999999
# k: 1 , max_depth: 7 gamma 10.0
# k: 2 , max_depth: 7 gamma 10.0
# k: 3 , max_depth: 7 gamma 10.0
# k: 4 , max_depth: 7 gamma 10.0
# WMAE: 1576.43
# k: 1 , max_depth: 8 gamma 0.0
# k: 2 , max_depth: 8 gamma 0.0
# k: 3 , max_depth: 8 gamma 0.0
# k: 4 , max_depth: 8 gamma 0.0
# WMAE: 1498.7775
# k: 1 , max_depth: 8 gamma 0.5
# k: 2 , max_depth: 8 gamma 0.5
# k: 3 , max_depth: 8 gamma 0.5
# k: 4 , max_depth: 8 gamma 0.5
# WMAE: 1498.2125
# k: 1 , max_depth: 8 gamma 1.0
# k: 2 , max_depth: 8 gamma 1.0
# k: 3 , max_depth: 8 gamma 1.0
# ...

# %% [markdown]
# > The result by the time I run it is 10, 0.5.

# %% [markdown]
# > Tuning 'lambda'.

# %%
xgboost_III(
    n_estimators=1500, 
    learning_rate=0.5, 
    max_depth=10,
    gamma=0.5,
    lambdas=[1e-5, 1e-2, 0.1, 1, 100]
)
# Out:
# k: 1 , lambda: 1e-05
# k: 2 , lambda: 1e-05
# k: 3 , lambda: 1e-05
# k: 4 , lambda: 1e-05
# WMAE: 1533.28
# k: 1 , lambda: 0.01
# k: 2 , lambda: 0.01
# k: 3 , lambda: 0.01
# k: 4 , lambda: 0.01
# WMAE: 1538.4650000000001
# k: 1 , lambda: 0.1
# k: 2 , lambda: 0.1
# k: 3 , lambda: 0.1
# k: 4 , lambda: 0.1
# WMAE: 1501.675
# k: 1 , lambda: 1
# k: 2 , lambda: 1
# k: 3 , lambda: 1
# k: 4 , lambda: 1
# WMAE: 1454.6125
# k: 1 , lambda: 100
# k: 2 , lambda: 100
# k: 3 , lambda: 100
# k: 4 , lambda: 100
# WMAE: 1422.6274999999998
#    Learning Rate  Estimators  Max Depth  Gamma     Lambda       WMAE
# 0            0.5        1500         10    0.5    0.00001  1533.2800
# 1            0.5        1500         10    0.5    0.01000  1538.4650
# 2            0.5        1500         10    0.5    0.10000  1501.6750
# 3            0.5        1500         10    0.5    1.00000  1454.6125
# 4            0.5        1500         10    0.5  100.00000  1422.6275

# %% [markdown]
# > The result by the time I run it is 100.

# %% [markdown]
# > The final model:

# %%
GB = XGBRegressor(
                    n_estimators=1500,
                    learning_rate=0.5,
                    max_depth=10,
                    min_child_weight=1,
                    gamma=0.5,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    objective= 'reg:squarederror',
                    n_jobs=-1,
                    scale_pos_weight=1,
                    reg_lambda=100,
                    seed=42
                )
GB.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, gamma=0.5, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.5, max_delta_step=0, max_depth=10,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1500, n_jobs=-1, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=42, reg_alpha=0,
#              reg_lambda=100, scale_pos_weight=1, seed=42, subsample=0.8,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Predictions

# %% [markdown]
# > Same fields for Test Data.

# %%
X_test = to_float(test_ds[['Store', 'Dept', 'IsHoliday', 'Size', 'Week', 'Type', 'Year']])
predict = GB.predict(X_test)

# %% [markdown]
# # 4-Christmas Adjustment

# %% [markdown]
# > Ok, now it's time to make the Christmas Adjustment.
#
# > We can remember that Christmas Week has 0 pre-holiday days in 2010, 1 in 2011 and 3 in 2012. So, it's a difference of 3 days from 2012 to 2010 and 2 days from 2012 to 2011. A 2.5 days average, in a week (7 days). So, this is the value that we are going to multiply to Week 51 and add to Week 52 to compensate what the model didn't take into account.
#
# > But we are going to use this formula just for 'Stores'+'Departments' that have a big difference between Week 51 and Week 52 Sales. Let's say Week51 > 2 * Week52.

# %% [markdown]
# > Let's use another dataframe and SQL to solve it quickly.

# %%
Final = X_test[['Store', 'Dept', 'Week']]
Final['Weekly_Sales'] = predict
# Out:
# /home/ubuntu/anaconda3/envs/ke/lib/python3.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
# !pip install pandasql

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
Final_adj = pysqldf("""
    SELECT
        Store,
        Dept,
        Week,
        Weekly_Sales,
        case 
            when Week = 52 and last_sales > 2*Weekly_Sales then Weekly_Sales+(2.5/7)*last_sales
            else Weekly_Sales 
        end as Weekly_Sales_Adjusted
    from(
        SELECT
            Store, 
            Dept, 
            Week, 
            Weekly_Sales,
            case 
                when Week = 52 then lag(Weekly_Sales) over(partition by Store, Dept) 
            end as last_sales
        from Final)""")

# %%
Final
# Out:
#         Store  Dept  Week  Weekly_Sales
# 0        37.0  61.0  44.0  37467.113281
# 1        37.0  61.0  45.0  14167.781250
# 2        37.0  61.0  46.0  14651.260742
# 3        37.0  61.0  47.0  14160.083008
# 4        37.0  61.0  48.0  22961.285156
# ...       ...   ...   ...           ...
# 115059   17.0  38.0  26.0    519.486023
# 115060   17.0  38.0  27.0   1146.490356
# 115061   17.0  38.0  28.0    563.146729
# 115062   17.0  38.0  29.0    542.504883
# 115063   17.0  38.0  30.0    227.247833
#
# [115064 rows x 4 columns]

# %% [markdown]
# After adjusting we have to resort records to match `Final`

# %%
Final_adj
# Out:
#         Store  Dept  Week   Weekly_Sales  Weekly_Sales_Adjusted
# 0         1.0   1.0   8.0    -140.286453            -140.286453
# 1         1.0   6.0  47.0     148.525650             148.525650
# 2         1.0   6.0   1.0      64.608665              64.608665
# 3         1.0   6.0   7.0       8.341666               8.341666
# 4         1.0   6.0   8.0     -75.636139             -75.636139
# ...       ...   ...   ...            ...                    ...
# 115059   45.0  81.0  26.0  155883.890625          155883.890625
# 115060   45.0  81.0  27.0  183294.953125          183294.953125
# 115061   45.0  81.0  28.0  184091.531250          184091.531250
# 115062   45.0  81.0  29.0  163075.859375          163075.859375
# 115063   45.0  81.0  30.0  151932.640625          151932.640625
#
# [115064 rows x 5 columns]

# %%
Final_adj = Final[['Store', 'Dept', 'Week']].merge(Final_adj, on=['Store', 'Dept', 'Week'])

# %%
Final_adj
# Out:
#         Store  Dept  Week  Weekly_Sales  Weekly_Sales_Adjusted
# 0        37.0  61.0  44.0  37467.113281           37467.113281
# 1        37.0  61.0  45.0  14167.781250           14167.781250
# 2        37.0  61.0  46.0  14651.260742           14651.260742
# 3        37.0  61.0  47.0  14160.083008           14160.083008
# 4        37.0  61.0  48.0  22961.285156           22961.285156
# ...       ...   ...   ...           ...                    ...
# 115059   17.0  38.0  26.0    519.486023             519.486023
# 115060   17.0  38.0  27.0   1146.490356            1146.490356
# 115061   17.0  38.0  28.0    563.146729             563.146729
# 115062   17.0  38.0  29.0    542.504883             542.504883
# 115063   17.0  38.0  30.0    227.247833             227.247833
#
# [115064 rows x 5 columns]

# %% [markdown]
# # Interpretation of Best Model

# %% [markdown]
# ## feature importances

# %%
plt.figure(figsize=(10,10))
pd.Series(GB.feature_importances_, index=X_train.columns).plot(kind='barh');

# %% [markdown]
# ## Permutation Feature importances

# %%
# !pip install eli5

# %%
import eli5
from eli5.sklearn import PermutationImportance
# Out:
# /home/ubuntu/anaconda3/envs/ke/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/ubuntu/anaconda3/envs/ke/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Using TensorFlow backend.

# %%
perm = PermutationImportance(GB, random_state=1).fit(X_train, Y_train)

# %%
eli5.show_weights(perm, feature_names = X_train.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 1.8058
#
#                     &plusmn; 0.0104
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Dept
#             </td>
# ...

# %% [markdown]
# # Predict on test set

# %% [markdown]
# ## Prepare submission file with original model predictions

# %%
submission = pd.read_csv('data/sampleSubmission.csv.zip')

# %%
submission['Weekly_Sales'] = Final_adj['Weekly_Sales']

# %%
submission.to_csv(f'{PATH}/submission.csv',index=False)

# %% [markdown]
# ## Prepare submission file with adjusted model predictions

# %%
submission_adjusted = pd.read_csv('data/sampleSubmission.csv.zip')

# %%
submission_adjusted['Weekly_Sales'] = Final_adj['Weekly_Sales_Adjusted']

# %%
submission_adjusted.to_csv(f'{PATH}/submission_adjusted.csv',index=False)

# %% [markdown]
# # Submission Scores

# %% [markdown]
# Final sumbission scores:
# - 2902.90729 public score for original predictions
# - 2755.18603 public score for adjusted predictions
